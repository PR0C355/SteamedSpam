# %%
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv
import json

# %%
load_dotenv()
client = OpenAI()

# %%
def generate_response(req_index, text):
  """
  Generates a request to classify spam messages using OpenAI's API.
  Args:
      req_index (str): The index of the request.
      text (str): The text to classify.
      Returns:
      dict: A dictionary containing the request details.
  """
  return {
    "custom_id": str(req_index),
    "method": "POST",
    "url": "/v1/chat/completions",
    "body": {
      "model": "gpt-4o-mini",
      "messages": [
        {
            "role": "system",
            "content": "Classify the following text as one of the following: finanical/banking spam, phishing spam, job/employment spam, malware spam, prize/lottery spam, or general spam. If the text does not fit any of these categories, classify it as 'general spam'."
        },
        {
            "role": "user",
            "content": text
        }
      ],
      "max_tokens": 4096,
      "response_format": {
        "type": "json_schema",
        "json_schema": {
            "name": "spam_classification",
            "schema": {
              "type": "object",
              "properties": {
                  "classification": {
                      "type": "string",
                      "enum": [
                          "financial/banking spam",
                          "phishing spam",
                          "job/employment spam",
                          "malware spam",
                          "prize/lottery spam",
                          "general spam"
                      ]
                  }
              },
              "required": ["classification"],
              "additionalProperties": False
            },
            "strict": True
        },
    }
    }
  }

# %%
def create_batch_file(csv_file, output_file):
    """
    Create a batch file for OpenAI API requests from a CSV file.
    Args:
        csv_file (str): Path to the input CSV file.
        output_file (str): Path to the output batch file.
    """
    raw_data = pd.read_csv(csv_file)
    raw_data = raw_data.reset_index()  # make sure indexes pair with number of rows

    batch_data = []

    for index, row in raw_data.iterrows():
        if row["label_num"] == 1:
            response = generate_response(
                index,
                row["text"]
            )
            batch_data.append(json.dumps(response))

    with open(output_file, "w") as f:
        for item in batch_data:
            f.write("%s\n" % item)

# %%
def process_batch_file(batch_file):
    """
    Process the batch file and extract the classification results.
    Args:
        batch_file (str): Path to the batch output file.
        Returns:
        dict: A dictionary mapping request indices to their classifications.
    """
    request_class_mapping = {}
    with open(batch_file, "r") as f:
        lines = f.readlines()

    for line in lines:
        response = json.loads(line)
        req_index = response["custom_id"]
        classification = json.loads(response["response"]["body"]["choices"][0]["message"]["content"])["classification"]
        request_class_mapping[req_index] = classification
        # print(f"Request Index: {req_index}, Classification: {classification}")
    return request_class_mapping

# %%
def apply_classifications(csv_file, request_class_mapping):
    """
    Apply the classifications to the original CSV file and save the results.
    Args:
        csv_file (str): Path to the input CSV file.
        request_class_mapping (dict): A dictionary mapping request indices to their classifications.
    """
    raw_data = pd.read_csv(csv_file)
    raw_data = raw_data.reset_index()  # make sure indexes pair with number of rows

    for index, row in raw_data.iterrows():
        if row["label_num"] == 1:
            classification = request_class_mapping.get(str(index), "unknown")
            raw_data.at[index, "classification"] = classification
        else:
            raw_data.at[index, "classification"] = "ham"

    raw_data.to_csv("classified_spam.csv", index=False)

# %%
create_batch_file("test_data.csv", "test_batch_input.jsonl")

# %%
print(process_batch_file("test_batch_output.jsonl"))
# Out:
# {'1': 'general spam'}

# %%
apply_classifications("test_data.csv", process_batch_file("test_batch_output.jsonl"))
# Out:
# Request Index: 1, Classification: general spam

# %%
create_batch_file("Raw Data/total_spam.csv", "04.05.2025_batch_input.jsonl")

# %%
apply_classifications("Raw Data/total_spam.csv", process_batch_file("batch_67f1a02ecdac819095c4763fab8486ef_output.jsonl"))

# %%
pd.read_csv("classified_spam.csv").head(40)
# Out:
#     index                                               text label  label_num  \
# 0       0  Subject: enron methanol ; meter # : 988291\r\n...   ham          0
# 1       1  Subject: hpl nom for january 9 , 2001\r\n( see...   ham          0
# 2       2  Subject: neon retreat\r\nho ho ho , we ' re ar...   ham          0
# 3       3  Subject: photoshop , windows , office . cheap ...  spam          1
# 4       4  Subject: re : indian springs\r\nthis deal is t...   ham          0
# 5       5  Subject: ehronline web address change\r\nthis ...   ham          0
# 6       6  Subject: spring savings certificate - take 30 ...   ham          0
# 7       7  Subject: looking for medication ? we ` re the ...  spam          1
# 8       8  Subject: noms / actual flow for 2 / 26\r\nwe a...   ham          0
# 9       9  Subject: nominations for oct . 21 - 23 , 2000\...   ham          0
# 10     10  Subject: vocable % rnd - word asceticism\r\nvc...  spam          1
# 11     11  Subject: report 01405 !\r\nwffur attion brom e...  spam          1
# 12     12  Subject: enron / hpl actuals for august 28 , 2...   ham          0
# 13     13  Subject: vic . odin n ^ ow\r\nberne hotbox car...  spam          1
# 14     14  Subject: tenaska iv july\r\ndarren :\r\nplease...   ham          0
# 15     15  Subject: underpriced issue with high return on...  spam          1
# 16     16  Subject: re : first delivery - wheeler operati...   ham          0
# 17     17  Subject: swift - may 2001 vols\r\nsean ,\r\nfy...   ham          0
# 18     18  Subject: meter variances - ua 4 clean - up\r\n...   ham          0
# 19     19  Subject: additional recruiting\r\ni ' m happy ...   ham          0
# 20     20  Subject: fw : ercot load comparison\r\n- - - -...   ham          0
# 21     21  Subject: meter 6461 , concorde churchill\r\non...   ham          0
# 22     22  Subject: hpl nom for january 25 , 2001\r\n( se...   ham          0
# 23     23  Subject: re : tenaska iv 10 / 00\r\nwe have re...   ham          0
# 24     24  Subject: jump in to gain substantial ground im...  spam          1
# 25     25  Subject: re : enron / hpl actuals for october ...   ham          0
# 26     26  Subject: registration confirmation from spinne...   ham          0
# 27     27  Subject: aep transition items\r\nattached is a...   ham          0
# 28     28  Subject: an inbound message for you has been q...   ham          0
# 29     29  Subject: re : valero gas marketing ; meter # :...   ham          0
# 30     30  Subject: the houston expl dec 2000\r\ndarren :...   ham          0
# 31     31  Subject: enron / hpl actuals for october 2 , 2...   ham          0
# 32     32  Subject: to : all domestic employees who parti...   ham          0
# 33     33  Subject: re : new eol product\r\nthe texas gas...   ham          0
# 34     34  Subject: pathing procedures for buybacks\r\nto...   ham          0
# 35     35  Subject: end of year clearance\r\nitem no #\r\...  spam          1
# 36     36  Subject: enron actuals for june 02 thru 04 , 2...   ham          0
# 37     37  Subject: on - call notes\r\nplease see the att...   ham          0
# 38     38  Subject: 19 th noms on copanos\r\n- - - - - - ...   ham          0
# 39     39  Subject: lst rev feb . 2000 josey ranch nom\r\...   ham          0
#
#         source   type          classification
# 0   spam_mails  email                     ham
# 1   spam_mails  email                     ham
# 2   spam_mails  email                     ham
# 3   spam_mails  email            general spam
# 4   spam_mails  email                     ham
# 5   spam_mails  email                     ham
# 6   spam_mails  email                     ham
# 7   spam_mails  email            general spam
# 8   spam_mails  email                     ham
# 9   spam_mails  email                     ham
# 10  spam_mails  email  financial/banking spam
# 11  spam_mails  email            general spam
# 12  spam_mails  email                     ham
# 13  spam_mails  email            general spam
# 14  spam_mails  email                     ham
# 15  spam_mails  email  financial/banking spam
# 16  spam_mails  email                     ham
# 17  spam_mails  email                     ham
# 18  spam_mails  email                     ham
# 19  spam_mails  email                     ham
# 20  spam_mails  email                     ham
# 21  spam_mails  email                     ham
# 22  spam_mails  email                     ham
# 23  spam_mails  email                     ham
# 24  spam_mails  email  financial/banking spam
# 25  spam_mails  email                     ham
# 26  spam_mails  email                     ham
# 27  spam_mails  email                     ham
# 28  spam_mails  email                     ham
# 29  spam_mails  email                     ham
# 30  spam_mails  email                     ham
# 31  spam_mails  email                     ham
# 32  spam_mails  email                     ham
# 33  spam_mails  email                     ham
# 34  spam_mails  email                     ham
# 35  spam_mails  email            general spam
# 36  spam_mails  email                     ham
# 37  spam_mails  email                     ham
# 38  spam_mails  email                     ham
# 39  spam_mails  email                     ham

# %%
print(process_batch_file("batch_67f1a02ecdac819095c4763fab8486ef_output.jsonl"))
# Out:
# {'3': 'general spam', '7': 'general spam', '10': 'financial/banking spam', '11': 'general spam', '13': 'general spam', '15': 'financial/banking spam', '24': 'financial/banking spam', '35': 'general spam', '40': 'general spam', '41': 'phishing spam', '46': 'general spam', '47': 'phishing spam', '48': 'general spam', '50': 'prize/lottery spam', '60': 'financial/banking spam', '68': 'financial/banking spam', '70': 'general spam', '71': 'prize/lottery spam', '74': 'general spam', '75': 'general spam', '85': 'general spam', '90': 'malware spam', '91': 'financial/banking spam', '92': 'general spam', '93': 'general spam', '94': 'general spam', '98': 'general spam', '103': 'general spam', '104': 'general spam', '106': 'general spam', '109': 'general spam', '110': 'general spam', '115': 'general spam', '124': 'general spam', '126': 'general spam', '128': 'general spam', '129': 'general spam', '134': 'general spam', '135': 'phishing spam', '137': 'financial/banking spam', '138': 'general spam', '139': 'general spam', '141': 'financial/banking spam', '144': 'general spam', '147': 'general spam', '154': 'general spam', '157': 'financial/banking spam', '158': 'malware spam', '162': 'general spam', '163': 'general spam', '164': 'general spam', '175': 'malware spam', '176': 'general spam', '179': 'general spam', '180': 'prize/lottery spam', '182': 'general spam', '184': 'general spam', '186': 'general spam', '191': 'general spam', '195': 'general spam', '208': 'general spam', '213': 'phishing spam', '218': 'general spam', '219': 'financial/banking spam', '223': 'financial/banking spam', '224': 'general spam', '231': 'general spam', '232': 'financial/banking spam', '233': 'general spam', '236': 'malware spam', '239': 'general spam', '241': 'financial/banking spam', '243': 'general spam', '244': 'general spam', '246': 'general spam', '248': 'financial/banking spam', '250': 'phishing spam', '253': 'prize/lottery spam', '255': 'general spam', '256': 'general spam', '257': 'general spam', '258': 'general spam', '260': 'general spam', '261': 'malware spam', '264': 'general spam', '266': 'phishing spam', '272': 'general spam', '274': 'general spam', '276': 'malware spam', '281': 'general spam', '284': 'general spam', '291': 'financial/banking spam', '295': 'general spam', '296': 'general spam', '298': 'general spam', '301': 'general spam', '305': 'general spam', '310': 'general spam', '314': 'financial/banking spam', '317': 'general spam', '318': 'general spam', '324': 'general spam', '327': 'general spam', '331': 'malware spam', '333': 'general spam', '334': 'malware spam', '335': 'general spam', '340': 'malware spam', '341': 'general spam', '344': 'general spam', '345': 'phishing spam', '350': 'general spam', '354': 'financial/banking spam', '359': 'general spam', '363': 'general spam', '366': 'general spam', '370': 'general spam', '373': 'general spam', '376': 'general spam', '388': 'general spam', '392': 'general spam', '397': 'general spam', '403': 'general spam', '404': 'general spam', '406': 'general spam', '407': 'general spam', '410': 'general spam', '412': 'general spam', '417': 'phishing spam', '419': 'financial/banking spam', '432': 'financial/banking spam', '433': 'financial/banking spam', '439': 'phishing spam', '445': 'financial/banking spam', '450': 'general spam', '459': 'general spam', '464': 'general spam', '468': 'general spam', '470': 'general spam', '471': 'malware spam', '476': 'general spam', '477': 'general spam', '481': 'general spam', '482': 'general spam', '485': 'general spam', '492': 'prize/lottery spam', '494': 'job/employment spam', '496': 'general spam', '498': 'general spam', '499': 'general spam', '500': 'general spam', '504': 'financial/banking spam', '507': 'job/employment spam', '510': 'malware spam', '515': 'general spam', '518': 'general spam', '522': 'general spam', '531': 'financial/banking spam', '533': 'financial/banking spam', '534': 'general spam', '537': 'financial/banking spam', '538': 'general spam', ...
